# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()

# %%
df = pd.read_excel('trial1_2013-2020.xlsx')
df.head()
# Out:
#         Date  X_Tp_BMD(mm)  Y_tp_sattelite(mm)
# 0 2013-01-01             0                0.56
# 1 2013-01-02             0                0.08
# 2 2013-01-03             0                0.01
# 3 2013-01-04             0                0.00
# 4 2013-01-05             0                0.00

# %%
# collecting X and Y
X = ['X_Tp_BMD(mm)']
Y = ['Y_tp_sattelite(mm)']

# %%
plt.figure(figsize=(20,10))
plt.scatter (X,Y)
