# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))

#reading data
data = pd.read_excel('trial1_2013-2020.xlsx')
print (data.shape)
data.head()
# Out:
# (2922, 3)
#         Date  X_Tp_BMD(mm)  Y_tp_sattelite(mm)
# 0 2013-01-01             0                0.56
# 1 2013-01-02             0                0.08
# 2 2013-01-03             0                0.01
# 3 2013-01-04             0                0.00
# 4 2013-01-05             0                0.00

# %%
# collecting X and Y
X = ['X_Tp_BMD(mm)']
Y = ['Y_tp_sattelite(mm)']

# %%
mean_x = print("Mean: ",data["X_Tp_BMD(mm)"].mean())
mean_y = print("Mean: ",data["Y_tp_sattelite(mm)"].mean())
# Out:
# Mean:  11.442505133470226
# Mean:  11.428405201916494

# %%
X-x = 'X_Tp_BMD(mm)' - 11.442505
Y-y = 'Y_tp_sattelite(mm)' - 11.428405
# Out:
#   File "<ipython-input-9-ceb1de4fe085>", line 1
#     X-x = 'X_Tp_BMD(mm)' - 11.442505
#                                     ^
# SyntaxError: can't assign to operator

# %%
#from tables import index
#total length of values
#n = len (X)
#using formula for calculating m and c

#for i in range (n)
#numer = (X[i] - mean_x)* (Y[i] - mean_y)
#denom = (X[i] - mean_x)**2
#m = numer/denom
#c = mean_y -(m*mean_x)
#print (m, c)
